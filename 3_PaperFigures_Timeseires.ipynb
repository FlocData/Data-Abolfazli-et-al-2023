# %% [markdown]
# # Paper Figures - Mississippi River Tank Data [Time Series]

# %% [markdown]
# ## Getting setup
#
# Python and NTU conversion equation loads

# %%
from math import nan
import numpy as np
import os as os
from glob import glob
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib widget
# %config InlineBackend.figure_format='retina' # hig-res plots for a Retina display
import datetime

# Set plot parameters -----------------------

plt.rcParams.update({'font.size': 8})
# ------ Half Page Width --------------------
wHP = 3.
hHP = 2.33
# ------ Full Page Width --------------------
wFP = 6
hFP = 3

# NTU to SSC calibration equations for the OBS

def NTU_C1(NTU):
    return 2.6836*NTU - 33.943

def NTU_C2(NTU):
    return 2.121*NTU

# Get the working directory and a list of folders that contain data by experiment

working = os.getcwd()
datadir = sorted(glob(working+"/Time_Series/*/"))
for i in range(0,len(datadir)):
    print('Data directory:',datadir[i],'(index:',i,')')
# Out:
# Data directory: /Users/strom-adm/My Drive/Frontiers Paper/Time_Series/Exp01_2020-06-26_Tank1/ (index: 0 )
# Data directory: /Users/strom-adm/My Drive/Frontiers Paper/Time_Series/Exp02_2020-06-27_Tank1/ (index: 1 )
# Data directory: /Users/strom-adm/My Drive/Frontiers Paper/Time_Series/Exp03_2020-06-28_Tank1/ (index: 2 )
# Data directory: /Users/strom-adm/My Drive/Frontiers Paper/Time_Series/Exp04_2020-06-29_Tank1/ (index: 3 )
# Data directory: /Users/strom-adm/My Drive/Frontiers Paper/Time_Series/Exp05_2020-06-30_Tank1/ (index: 4 )
# Data directory: /Users/strom-adm/My Drive/Frontiers Paper/Time_Series/Exp06_2020-07-02_Tank1/ (index: 5 )
# Data directory: /Users/strom-adm/My Drive/Frontiers Paper/Time_Series/Exp07_2020-06-25_Tank2/ (index: 6 )
# Data directory: /Users/strom-adm/My Drive/Frontiers Paper/Time_Series/Exp08_2020-06-26_Tank2/ (index: 7 )
# Data directory: /Users/strom-adm/My Drive/Frontiers Paper/Time_Series/Exp09_2020-06-27_Tank2/ (index: 8 )
# Data directory: /Users/strom-adm/My Drive/Frontiers Paper/Time_Series/Exp10_2020-06-29_Tank2/ (index: 9 )
# Data directory: /Users/strom-adm/My Drive/Frontiers Paper/Time_Series/Exp11_2020-06-30_Tank2/ (index: 10 )
# Data directory: /Users/strom-adm/My Drive/Frontiers Paper/Time_Series/Exp12_2020-07-02_Tank2/ (index: 11 )
# Data directory: /Users/strom-adm/My Drive/Frontiers Paper/Time_Series/Exp13_2021-01-08_Tank1/ (index: 12 )
# Data directory: /Users/strom-adm/My Drive/Frontiers Paper/Time_Series/Exp14_2021-01-09_Tank1/ (index: 13 )
# Data directory: /Users/strom-adm/My Drive/Frontiers Paper/Time_Series/Exp15_2021-01-10_Tank1/ (index: 14 )
# Data directory: /Users/strom-adm/My Drive/Frontiers Paper/Time_Series/Exp16_2021-01-11_Tank1/ (index: 15 )
# Data directory: /Users/strom-adm/My Drive/Frontiers Paper/Time_Series/Exp17_2021-01-13_Tank1/ (index: 16 )
# Data directory: /Users/strom-adm/My Drive/Frontiers Paper/Time_Series/Exp18_2021-01-14_Tank1/ (index: 17 )
# Data directory: /Users/strom-adm/My Drive/Frontiers Paper/Time_Series/Exp19_2021-01-08_Tank2/ (index: 18 )
# Data directory: /Users/strom-adm/My Drive/Frontiers Paper/Time_Series/Exp20_2021-01-09_Tank2/ (index: 19 )
# Data directory: /Users/strom-adm/My Drive/Frontiers Paper/Time_Series/Exp21_2021-01-10_Tank2/ (index: 20 )
# Data directory: /Users/strom-adm/My Drive/Frontiers Paper/Time_Series/Exp22_2021-01-11_Tank2/ (index: 21 )
# Data directory: /Users/strom-adm/My Drive/Frontiers Paper/Time_Series/Exp23_2021-01-13_Tank2/ (index: 22 )
# Data directory: /Users/strom-adm/My Drive/Frontiers Paper/Time_Series/Exp24_2021-01-14_Tank2/ (index: 23 )

# %% [markdown]
# ## Sample time series

# %%
j = 2 # grab data from exp03 ------------------------------------

# grab the folder name

expname = os.path.basename(os.path.dirname(datadir[j]))
expinfo = expname.split('_') # break the folder down to get the exp num (i=0), date (i=1), and tank info (i=2)

# set the path to the .csv files

sizedata = datadir[j] + '/size_aligned.csv'
GSdata = datadir[j] + '/G_S_data.csv'
OBSdata = datadir[j] + '/obs_aligned.csv'

# read in the data

size = pd.read_csv(sizedata)
GS = pd.read_csv(GSdata)
obs = pd.read_csv(OBSdata)

obs['mgL'] = NTU_C1(obs['NTU']) # add in a SSC column using the OBS calibration

# build the labels table for placing "break" marks and labels on figures

labels = GS[0:-1:2].copy()
labels.reset_index(inplace = True,drop = True)

# set the plot parameter ranges and colors

Gmin = 5
Gmax = 100
    
Smin = -5
Smax = 35

dmin = 20
dmax = 275

cminMGL = min(obs['mgL'])-5
cmaxMGL = 120

cminNTU = 0
cmaxNTU = 110

xmin = 0
xmax = GS['min'].iloc[-1]
xmax = 375

# gcolor = 'C3'
# scolor = 'C2'
# d50color = 'C0'
# d84color = 'C3'
# ccolor = 'k'

gcolor = 'C3'
scolor = 'C0'
d50color = 'C0'
d84color = 'C8'
ccolor = 'C1'

# make the figure

fig = plt.figure(figsize=(wFP,hFP))

gs = fig.add_gridspec(2,hspace=0, height_ratios=[2,3])
axs = gs.subplots(sharex=True, sharey=False)

axs[0].plot(GS['min'], GS['G_Hz'], color=gcolor, alpha=1, label='$G$')
axs[0].set_ylabel('$G$ [$\mathrm{s^{-1}}$]')

axs_twin1 = axs[0].twinx()
axs_twin1.plot(GS['min'], GS['S_ppt'], linestyle = '-.',color=scolor, alpha=1, label='$S$')
axs_twin1.set_ylabel('$S$ [psu]')
axs_twin1.set_ylim(Smin,Smax)

# axs[0].set_xlim(xmin,xmax)
axs[0].set_ylim(Gmin,Gmax)
axs[0].text(xmax-0.1*xmax,65, expinfo[0]+'\n(GoM)', # backgroundcolor='white', 
        clip_on='True', multialignment='center', alpha=1) #weight = 'bold'

li1,la1 = axs[0].get_legend_handles_labels()
li2,la2 = axs_twin1.get_legend_handles_labels()

axs[0].legend(li1+li2,la1+la2,loc=3)

if 'd84_mu' in size.columns:
    axs[1].plot(size['min_from_start'], size['d84_mu'],'o', color=d84color, alpha=0.5,label='$d_{84}$')
axs[1].plot(size['min_from_start'], size['d50_mu'],'o', color=d50color, alpha=0.5,label='$d_{50}$')
axs[1].set_ylabel('$d_{\mathit{floc}}$ [µm]')
axs[1].set_xlabel('Time [min]')
axs[1].set_ylim(dmin,dmax)
axs[1].set_xlim(xmin,xmax)
for i in range(1,len(labels)):
    axs[1].axvline(x=labels['min'][i],color='k', linestyle='--', alpha=0.5)

axs_twin2 = axs[1].twinx()
# axs_twin2.plot(obs['min_from_start'], obs['mgL'], color=ccolor, alpha = 1,label='$C$')
# axs_twin2.set_ylabel('$C$ [mg/L]')
# axs_twin2.set_ylim(cminMGL,cmaxMGL)
axs_twin2.plot(obs['min_from_start'], obs['NTU'], color=ccolor, alpha = 1,label='$C$')
axs_twin2.set_ylabel('$C$ [NTU]')
axs_twin2.set_ylim(cminNTU,cmaxNTU)

li3,la3 = axs[1].get_legend_handles_labels()
li4,la4 = axs_twin2.get_legend_handles_labels()

axs[1].legend(li3+li4,la3+la4,loc=2)
    
fig.tight_layout();
plt.savefig('Figures/TS_example_'+expinfo[0]+'.pdf',bbox_inches="tight", pad_inches=0.005)

# %% [markdown]
# second

# %%
j = 8 # grab data from exp03 ------------------------------------

# grab the folder name

expname = os.path.basename(os.path.dirname(datadir[j]))
expinfo = expname.split('_') # break the folder down to get the exp num (i=0), date (i=1), and tank info (i=2)

# set the path to the .csv files

sizedata = datadir[j] + '/size_aligned.csv'
GSdata = datadir[j] + '/G_S_data.csv'
OBSdata = datadir[j] + '/obs_aligned.csv'

# read in the data

size = pd.read_csv(sizedata)
GS = pd.read_csv(GSdata)
obs = pd.read_csv(OBSdata)

obs['mgL'] = NTU_C1(obs['NTU']) # add in a SSC column using the OBS calibration

# build the labels table for placing "break" marks and labels on figures

labels = GS[0:-1:2].copy()
labels.reset_index(inplace = True,drop = True)

# set the plot parameter ranges and colors

Gmin = 5
Gmax = 100
    
Smin = -5
Smax = 35

dmin = 20
dmax = 275

cminMGL = min(obs['mgL'])-5
cmaxMGL = 120

cminNTU = 0
cmaxNTU = 110

xmin = 0
xmax = GS['min'].iloc[-1]
# xmax = 375

# gcolor = 'C3'
# scolor = 'C2'
# d50color = 'C0'
# d84color = 'C3'
# ccolor = 'k'

gcolor = 'C3'
scolor = 'C0'
d50color = 'C0'
d84color = 'C8'
ccolor = 'C1'

# make the figure

fig = plt.figure(figsize=(wFP,hFP))

gs = fig.add_gridspec(2,hspace=0, height_ratios=[2,3])
axs = gs.subplots(sharex=True, sharey=False)

axs[0].plot(GS['min'], GS['G_Hz'], color=gcolor, alpha=1, label='$G$')
axs[0].set_ylabel('$G$ [$\mathrm{s^{-1}}$]')

axs_twin1 = axs[0].twinx()
axs_twin1.plot(GS['min'], GS['S_ppt'], linestyle = '-.',color=scolor, alpha=1, label='$S$')
axs_twin1.set_ylabel('$S$ [psu]')
axs_twin1.set_ylim(Smin,Smax)

# axs[0].set_xlim(xmin,xmax)
axs[0].set_ylim(Gmin,Gmax)
axs[0].text(xmax-0.2*xmax,80, expinfo[0]+' (no GoM)', # backgroundcolor='white', 
        clip_on='True', multialignment='center', alpha=1) #weight = 'bold'

li1,la1 = axs[0].get_legend_handles_labels()
li2,la2 = axs_twin1.get_legend_handles_labels()

axs[0].legend(li1+li2,la1+la2,loc=4)

if 'd84_mu' in size.columns:
    axs[1].plot(size['min_from_start'], size['d84_mu'],'o', color=d84color, alpha=0.5,label='$d_{84}$')
axs[1].plot(size['min_from_start'], size['d50_mu'],'o', color=d50color, alpha=0.5,label='$d_{50}$')
axs[1].set_ylabel('$d_{\mathit{floc}}$ [µm]')
axs[1].set_xlabel('Time [min]')
axs[1].set_ylim(dmin,dmax)
axs[1].set_xlim(xmin,xmax)
for i in range(1,len(labels)):
    axs[1].axvline(x=labels['min'][i],color='k', linestyle='--', alpha=0.5)

axs_twin2 = axs[1].twinx()
# axs_twin2.plot(obs['min_from_start'], obs['mgL'], color=ccolor, alpha = 1,label='$C$')
# axs_twin2.set_ylabel('$C$ [mg/L]')
# axs_twin2.set_ylim(cminMGL,cmaxMGL)
axs_twin2.plot(obs['min_from_start'], obs['NTU'], color=ccolor, alpha = 1,label='$C$')
axs_twin2.set_ylabel('$C$ [NTU]')
axs_twin2.set_ylim(cminNTU,cmaxNTU)

li3,la3 = axs[1].get_legend_handles_labels()
li4,la4 = axs_twin2.get_legend_handles_labels()

axs[1].legend(li3+li4,la3+la4,loc=1)
    
fig.tight_layout();
plt.savefig('Figures/TS_example_'+expinfo[0]+'.pdf',bbox_inches="tight", pad_inches=0.005)

# %% [markdown]
# Third

# %%
j = 12 # grab data from exp03 ------------------------------------

# grab the folder name

expname = os.path.basename(os.path.dirname(datadir[j]))
expinfo = expname.split('_') # break the folder down to get the exp num (i=0), date (i=1), and tank info (i=2)

# set the path to the .csv files

sizedata = datadir[j] + '/size_aligned.csv'
GSdata = datadir[j] + '/G_S_data.csv'
OBSdata = datadir[j] + '/obs_aligned.csv'

# read in the data

size = pd.read_csv(sizedata)
GS = pd.read_csv(GSdata)
obs = pd.read_csv(OBSdata)

obs['mgL'] = NTU_C1(obs['NTU']) # add in a SSC column using the OBS calibration

# build the labels table for placing "break" marks and labels on figures

labels = GS[0:-1:2].copy()
labels.reset_index(inplace = True,drop = True)

# set the plot parameter ranges and colors

Gmin = 5
Gmax = 100
    
Smin = -5
Smax = 35

dmin = 20
dmax = 275

cminMGL = min(obs['mgL'])-5
cmaxMGL = 120

cminNTU = 0
cmaxNTU = 110

xmin = 0
xmax = GS['min'].iloc[-1]
# xmax = 375

# gcolor = 'C3'
# scolor = 'C2'
# d50color = 'C0'
# d84color = 'C3'
# ccolor = 'k'

gcolor = 'C3'
scolor = 'C0'
d50color = 'C0'
d84color = 'C8'
ccolor = 'C1'

# make the figure

fig = plt.figure(figsize=(wFP,hFP))

gs = fig.add_gridspec(2,hspace=0, height_ratios=[2,3])
axs = gs.subplots(sharex=True, sharey=False)

axs[0].plot(GS['min'], GS['G_Hz'], color=gcolor, alpha=1, label='$G$')
axs[0].set_ylabel('$G$ [$\mathrm{s^{-1}}$]')

axs_twin1 = axs[0].twinx()
axs_twin1.plot(GS['min'], GS['S_ppt'], linestyle = '-.',color=scolor, alpha=1, label='$S$')
axs_twin1.set_ylabel('$S$ [psu]')
axs_twin1.set_ylim(Smin,Smax)

# axs[0].set_xlim(xmin,xmax)
axs[0].set_ylim(Gmin,Gmax)
axs[0].text(xmax-0.125*xmax,65, expinfo[0]+'\n(no GoM)', # backgroundcolor='white', 
        clip_on='True', multialignment='center', alpha=1) #weight = 'bold'

li1,la1 = axs[0].get_legend_handles_labels()
li2,la2 = axs_twin1.get_legend_handles_labels()

axs[0].legend(li1+li2,la1+la2,loc=2)

if 'd84_mu' in size.columns:
    axs[1].plot(size['min_from_start'], size['d84_mu'],'o', color=d84color, alpha=0.5,label='$d_{84}$')
axs[1].plot(size['min_from_start'], size['d50_mu'],'o', color=d50color, alpha=0.5,label='$d_{50}$')
axs[1].set_ylabel('$d_{\mathit{floc}}$ [µm]')
axs[1].set_xlabel('Time [min]')
axs[1].set_ylim(dmin,dmax)
axs[1].set_xlim(xmin,xmax)
for i in range(1,len(labels)):
    axs[1].axvline(x=labels['min'][i],color='k', linestyle='--', alpha=0.5)

axs_twin2 = axs[1].twinx()
# axs_twin2.plot(obs['min_from_start'], obs['mgL'], color=ccolor, alpha = 1,label='$C$')
# axs_twin2.set_ylabel('$C$ [mg/L]')
# axs_twin2.set_ylim(cminMGL,cmaxMGL)
axs_twin2.plot(obs['min_from_start'], obs['NTU'], color=ccolor, alpha = 1,label='$C$')
axs_twin2.set_ylabel('$C$ [NTU]')
axs_twin2.set_ylim(cminNTU,cmaxNTU)

li3,la3 = axs[1].get_legend_handles_labels()
li4,la4 = axs_twin2.get_legend_handles_labels()

axs[1].legend(li3+li4,la3+la4,loc=2)
    
fig.tight_layout();
plt.savefig('Figures/TS_example_'+expinfo[0]+'.pdf',bbox_inches="tight", pad_inches=0.005)

# %% [markdown]
# ## Growth and Breakup Rates

# %%
# pick the experiment number to look at (index value is Exp number -1)

# includes the summertime experiment Exp03
# exp = np.array([13,15,14,17,3])
# saltype = ['no GoM','no GoM','no GoM','GoM','GoM']

# growth_start = np.array([0,0,0,0,1]) #section 
# growth_end = np.array([1,1,1,1,2])  #section

# break_start = np.array([1,1,1,1,4]) #section 
# break_end = np.array([2,2,2,2,5])  #section

# all wintertime experiments with similar G patters
exp = np.array([13,15,14,17])
saltype = ['no GoM','no GoM','no GoM','GoM']

growth_start = np.array([0,0,0,0]) #section 
growth_end = np.array([1,1,1,1])  #section

break_start = np.array([1,1,1,1]) #section 
break_end = np.array([2,2,2,2])  #section


# fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(wFP,hFP))

fig = plt.figure(figsize=(wFP,hHP))
gs = fig.add_gridspec(nrows=1, ncols=2,wspace=0)
ax = gs.subplots(sharex=False, sharey=True)

for i in range(0,len(exp)):
    
    j = exp[i] - 1

    # grab the folder name

    expname = os.path.basename(os.path.dirname(datadir[j]))
    expinfo = expname.split('_') # break the folder down to get the exp num (i=0), date (i=1), and tank info (i=2)

    # set the path to the .csv files

    sizedata = datadir[j] + '/size_aligned.csv'
    GSdata = datadir[j] + '/G_S_data.csv'

    # read in the data

    size = pd.read_csv(sizedata)
    GS = pd.read_csv(GSdata)
    
    # build the labels table for placing "break" marks and labels on figures

    labels = GS[0:-1:2].copy()
    labels.reset_index(inplace = True,drop = True)

    # plot the data
    
    growth = size[(size['min_from_start'] > labels['min'][growth_start[i]]) & (size['min_from_start'] < labels['min'][growth_end[i]])].copy()
    
    if break_end[i]<len(labels):
        breakup = size[(size['min_from_start'] > labels['min'][break_start[i]]) & (size['min_from_start'] < labels['min'][break_end[i]])].copy()
    else:
        breakup = size[(size['min_from_start'] > labels['min'][break_start[i]]) ].copy()
    
    # breakup = size[(size['min_from_start'] > labels['min'][break_start[i]]) & (size['min_from_start'] < labels['min'][break_end[i]])].copy()

    growth_G = labels['G_Hz'][growth_start[i]]
    growth_S = labels['S_ppt'][growth_start[i]]

    break_Gbefore = labels['G_Hz'][break_start[i]-1]
    break_Gduring = labels['G_Hz'][break_start[i]]

    ax[0].plot(growth['min_from_start']-labels['min'][growth_start[i]], growth['d50_mu'],'o',  alpha=0.5,
               label='$G=$'+str(growth_G)+'$\mathrm{s^{-1}}$, $S=$'+str(growth_S)+' psu ('+saltype[i]+') Exp'+str(exp[i]))

    ax[1].plot(breakup['min_from_start']-labels['min'][break_start[i]], breakup['d50_mu'],'o',  alpha=0.5,
               label='$G=$'+str(break_Gbefore)+r'$\rightarrow$'+str(break_Gduring)+'$\mathrm{s^{-1}}$, $S=$'+str(growth_S)+' psu ('+saltype[i]+')' )

    
ax[0].axvspan(150, 200, color='gray', alpha=0.25, lw=0)
ax[0].axvspan(350, 450, color='gray', alpha=0.25, lw=0)

ax[0].text(0,135, 'Growth', # backgroundcolor='white', 
        clip_on='True', multialignment='left', alpha=1) #weight = 'bold'

ax[0].text(143,30, 'GoM', # backgroundcolor='white', 
        clip_on='True', multialignment='left', alpha=1) #weight = 'bold'

ax[0].text(347,30, 'no GoM', # backgroundcolor='white', 
        clip_on='True', multialignment='left', alpha=1) #weight = 'bold'

ax[0].set_ylabel('$d_{\mathit{50}}$ [µm]')
ax[0].set_xlabel('Time [min]')
ax[0].set_ylim(dmin,dmax)
ax[0].legend(fontsize='7',loc=2)

# ax[1].set_ylabel('$d_{\mathit{50}}$ [µm]')
ax[1].set_xlabel('Time [min]')
ax[1].set_ylim(dmin,dmax)

ax[1].axvspan(15, 25, color='gray', alpha=0.25, lw=0)

ax[1].text(0,135, 'Breakup', # backgroundcolor='white', 
        clip_on='True', multialignment='left', alpha=1) #weight = 'bold'

ax[1].legend(fontsize='7',loc=2)
fig.tight_layout();
plt.savefig('Figures/GrowthBreakup_TimeScales.pdf',bbox_inches="tight", pad_inches=0.005)
